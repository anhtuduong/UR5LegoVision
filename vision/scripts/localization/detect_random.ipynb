# %%
import os
import random
from BlockDetect import BlockDetect

# Path to image folder
test_path = '/home/toto/ros_ws/src/UR5LegoVision/vision/dataset/test/images/'


# Number of sample to test
NUM_IMG = 10
for i in range(NUM_IMG):

    # Randomly pick img
    img_path = test_path + random.choice(os.listdir(test_path))
    print(img_path)

    legoDetect = BlockDetect(img_path)
# Out:
# /home/toto/ros_ws/src/UR5LegoVision/vision/dataset/test/images/v5_single_v2-X2-Y2-Z2-FILLET_DOWN_4523_png.rf.be218f1cffca9527b38e619c22539543.jpg
# [DEBUG]	DETECTING BLOCKS...
# [DEBUG]	Using YOLOv8: /home/toto/ros_ws/src/UR5LegoVision/vision/yolov8-training/600_epochs/weights/best.pt
# image 1/1 /home/toto/ros_ws/src/UR5LegoVision/vision/dataset/test/images/v5_single_v2-X2-Y2-Z2-FILLET_DOWN_4523_png.rf.be218f1cffca9527b38e619c22539543.jpg: 640x640 1 X2-Y2-Z2-FILLET, 630.7ms
# Speed: 4.4ms preprocess, 630.7ms inference, 10.3ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict
# [INFO]	Detected 1 object(s)
# [DEBUG]	1: X2-Y2-Z2-FILLET conf(0.99) xyxy(200, 167, 437, 406)
# <PIL.Image.Image image mode=RGB size=70x70>
# /home/toto/ros_ws/src/UR5LegoVision/vision/dataset/test/images/v5-X1-Y3-Z2_X1-Y4-Z1_DOWN_1121_png.rf.4d8c77530c868ce6e23694697afc87eb.jpg
# [DEBUG]	DETECTING BLOCKS...
# [DEBUG]	Using YOLOv8: /home/toto/ros_ws/src/UR5LegoVision/vision/yolov8-training/600_epochs/weights/best.pt
# image 1/1 /home/toto/ros_ws/src/UR5LegoVision/vision/dataset/test/images/v5-X1-Y3-Z2_X1-Y4-Z1_DOWN_1121_png.rf.4d8c77530c868ce6e23694697afc87eb.jpg: 640x640 2 X1-Y3-Z2s, 2 X1-Y4-Z1s, 575.0ms
# Speed: 45.1ms preprocess, 575.0ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict
# [INFO]	Detected 4 object(s)
# [DEBUG]	1: X1-Y3-Z2 conf(0.99) xyxy(376, 279, 615, 451)
# <PIL.Image.Image image mode=RGB size=70x50>
# [DEBUG]	2: X1-Y3-Z2 conf(0.99) xyxy(60, 161, 267, 317)
# <PIL.Image.Image image mode=RGB size=70x52>
# [DEBUG]	3: X1-Y4-Z1 conf(0.99) xyxy(268, 120, 509, 263)
# <PIL.Image.Image image mode=RGB size=70x41>
# [DEBUG]	4: X1-Y4-Z1 conf(0.99) xyxy(90, 365, 387, 559)
# <PIL.Image.Image image mode=RGB size=70x45>
# /home/toto/ros_ws/src/UR5LegoVision/vision/dataset/test/images/v5_single_v2-X1-Y3-Z2_DOWN_2421_png.rf.861c87007c125f06c95b585cbda9e5da.jpg
# [DEBUG]	DETECTING BLOCKS...
# [DEBUG]	Using YOLOv8: /home/toto/ros_ws/src/UR5LegoVision/vision/yolov8-training/600_epochs/weights/best.pt
# image 1/1 /home/toto/ros_ws/src/UR5LegoVision/vision/dataset/test/images/v5_single_v2-X1-Y3-Z2_DOWN_2421_png.rf.861c87007c125f06c95b585cbda9e5da.jpg: 640x640 1 X1-Y3-Z2, 606.6ms
# Speed: 44.6ms preprocess, 606.6ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict
# [INFO]	Detected 1 object(s)
# [DEBUG]	1: X1-Y3-Z2 conf(0.99) xyxy(195, 194, 448, 360)
# <PIL.Image.Image image mode=RGB size=70x45>
# /home/toto/ros_ws/src/UR5LegoVision/vision/dataset/test/images/v5_single_v2-X1-Y2-Z2-CHAMFER_UP_1305_png.rf.2384ecd84af0587afd1ed21559b100f6.jpg
# [DEBUG]	DETECTING BLOCKS...
# [DEBUG]	Using YOLOv8: /home/toto/ros_ws/src/UR5LegoVision/vision/yolov8-training/600_epochs/weights/best.pt
# image 1/1 /home/toto/ros_ws/src/UR5LegoVision/vision/dataset/test/images/v5_single_v2-X1-Y2-Z2-CHAMFER_UP_1305_png.rf.2384ecd84af0587afd1ed21559b100f6.jpg: 640x640 1 X1-Y2-Z2-CHAMFER, 669.0ms
# Speed: 1.5ms preprocess, 669.0ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict
# [INFO]	Detected 1 object(s)
# [DEBUG]	1: X1-Y2-Z2-CHAMFER conf(0.99) xyxy(237, 237, 408, 385)
# <PIL.Image.Image image mode=RGB size=70x60>
# /home/toto/ros_ws/src/UR5LegoVision/vision/dataset/test/images/v5-X1-Y3-Z2-FILLET_X2-Y2-Z2_UP_1274_png.rf.82436804d59435781e4a2312a31c3dc3.jpg
# [DEBUG]	DETECTING BLOCKS...
# [DEBUG]	Using YOLOv8: /home/toto/ros_ws/src/UR5LegoVision/vision/yolov8-training/600_epochs/weights/best.pt
# image 1/1 /home/toto/ros_ws/src/UR5LegoVision/vision/dataset/test/images/v5-X1-Y3-Z2-FILLET_X2-Y2-Z2_UP_1274_png.rf.82436804d59435781e4a2312a31c3dc3.jpg: 640x640 2 X1-Y3-Z2-FILLETs, 2 X2-Y2-Z2s, 590.4ms
# Speed: 1.9ms preprocess, 590.4ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict
# [INFO]	Detected 4 object(s)
# [DEBUG]	1: X2-Y2-Z2 conf(0.99) xyxy(133, 363, 334, 570)
# <PIL.Image.Image image mode=RGB size=70x72>
# [DEBUG]	2: X2-Y2-Z2 conf(0.99) xyxy(308, 108, 462, 280)
# <PIL.Image.Image image mode=RGB size=70x78>
# [DEBUG]	3: X1-Y3-Z2-FILLET conf(0.99) xyxy(374, 321, 599, 465)
# <PIL.Image.Image image mode=RGB size=70x44>
# [DEBUG]	4: X1-Y3-Z2-FILLET conf(0.99) xyxy(83, 208, 270, 333)
# <PIL.Image.Image image mode=RGB size=70x46>
# /home/toto/ros_ws/src/UR5LegoVision/vision/dataset/test/images/bg-125_jpg.rf.1c1fd1bb758085ac5915be075f52d287.jpg
# [DEBUG]	DETECTING BLOCKS...
# [DEBUG]	Using YOLOv8: /home/toto/ros_ws/src/UR5LegoVision/vision/yolov8-training/600_epochs/weights/best.pt
# image 1/1 /home/toto/ros_ws/src/UR5LegoVision/vision/dataset/test/images/bg-125_jpg.rf.1c1fd1bb758085ac5915be075f52d287.jpg: 640x640 (no detections), 615.9ms
# Speed: 18.4ms preprocess, 615.9ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict
# [INFO]	Detected 0 object(s)
# /home/toto/ros_ws/src/UR5LegoVision/vision/dataset/test/images/v5_single_v2-X1-Y2-Z1_SIDE_853_png.rf.9000269ec1dc640bac779bc2080e028f.jpg
# [DEBUG]	DETECTING BLOCKS...
# [DEBUG]	Using YOLOv8: /home/toto/ros_ws/src/UR5LegoVision/vision/yolov8-training/600_epochs/weights/best.pt
# image 1/1 /home/toto/ros_ws/src/UR5LegoVision/vision/dataset/test/images/v5_single_v2-X1-Y2-Z1_SIDE_853_png.rf.9000269ec1dc640bac779bc2080e028f.jpg: 640x640 1 X1-Y2-Z1, 570.2ms
# Speed: 9.5ms preprocess, 570.2ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict
# [INFO]	Detected 1 object(s)
# [DEBUG]	1: X1-Y2-Z1 conf(0.99) xyxy(221, 241, 384, 361)
# <PIL.Image.Image image mode=RGB size=70x51>
# /home/toto/ros_ws/src/UR5LegoVision/vision/dataset/test/images/v5_single_v2-X1-Y2-Z2-CHAMFER_DOWN_1491_png.rf.486ac1e5bb6110535d75a209c38951b6.jpg
# [DEBUG]	DETECTING BLOCKS...
# [DEBUG]	Using YOLOv8: /home/toto/ros_ws/src/UR5LegoVision/vision/yolov8-training/600_epochs/weights/best.pt
# image 1/1 /home/toto/ros_ws/src/UR5LegoVision/vision/dataset/test/images/v5_single_v2-X1-Y2-Z2-CHAMFER_DOWN_1491_png.rf.486ac1e5bb6110535d75a209c38951b6.jpg: 640x640 1 X1-Y2-Z2-CHAMFER, 608.5ms
# Speed: 22.6ms preprocess, 608.5ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict
# [INFO]	Detected 1 object(s)
# [DEBUG]	1: X1-Y2-Z2-CHAMFER conf(0.99) xyxy(235, 185, 408, 386)
# <PIL.Image.Image image mode=RGB size=70x81>
# /home/toto/ros_ws/src/UR5LegoVision/vision/dataset/test/images/v5-X1-Y2-Z2_X1-Y2-Z2-TWINFILLET_DOWN_558_png.rf.0c5b6f73759a1b9c8d14064c7bd208cc.jpg
# [DEBUG]	DETECTING BLOCKS...
# [DEBUG]	Using YOLOv8: /home/toto/ros_ws/src/UR5LegoVision/vision/yolov8-training/600_epochs/weights/best.pt
# image 1/1 /home/toto/ros_ws/src/UR5LegoVision/vision/dataset/test/images/v5-X1-Y2-Z2_X1-Y2-Z2-TWINFILLET_DOWN_558_png.rf.0c5b6f73759a1b9c8d14064c7bd208cc.jpg: 640x640 2 X1-Y2-Z2s, 2 X1-Y2-Z2-TWINFILLETs, 553.2ms
# Speed: 26.9ms preprocess, 553.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict
# [INFO]	Detected 4 object(s)
# [DEBUG]	1: X1-Y2-Z2 conf(0.99) xyxy(425, 257, 579, 371)
# <PIL.Image.Image image mode=RGB size=70x51>
# [DEBUG]	2: X1-Y2-Z2 conf(0.99) xyxy(61, 231, 220, 344)
# <PIL.Image.Image image mode=RGB size=70x49>
# [DEBUG]	3: X1-Y2-Z2-TWINFILLET conf(0.99) xyxy(217, 411, 382, 521)
# <PIL.Image.Image image mode=RGB size=70x46>
# [DEBUG]	4: X1-Y2-Z2-TWINFILLET conf(0.99) xyxy(270, 114, 396, 223)
# <PIL.Image.Image image mode=RGB size=70x60>
# /home/toto/ros_ws/src/UR5LegoVision/vision/dataset/test/images/v5_single_v2-X1-Y3-Z2_SIDE_2507_png.rf.ba6e533097daec8dcdb3c396b3e7d0bf.jpg
# [DEBUG]	DETECTING BLOCKS...
# [DEBUG]	Using YOLOv8: /home/toto/ros_ws/src/UR5LegoVision/vision/yolov8-training/600_epochs/weights/best.pt
# image 1/1 /home/toto/ros_ws/src/UR5LegoVision/vision/dataset/test/images/v5_single_v2-X1-Y3-Z2_SIDE_2507_png.rf.ba6e533097daec8dcdb3c396b3e7d0bf.jpg: 640x640 1 X1-Y3-Z2, 604.4ms
# Speed: 34.7ms preprocess, 604.4ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict
# [INFO]	Detected 1 object(s)
# [DEBUG]	1: X1-Y3-Z2 conf(0.99) xyxy(149, 189, 392, 413)
# <PIL.Image.Image image mode=RGB size=70x64>
