# %%
import os
import random
from BlockDetect import BlockDetect

# Path to image folder
test_path = '/home/toto/ros_ws/src/UR5LegoVision/vision/dataset/test/images/'


# Number of sample to test
NUM_IMG = 10
for i in range(NUM_IMG):

    # Randomly pick img
    img_path = test_path + random.choice(os.listdir(test_path))
    print(img_path)

    legoDetect = BlockDetect(img_path)
# Out:
# /home/toto/ros_ws/src/UR5LegoVision/vision/dataset/test/images/v5_single_v2-X2-Y2-Z2_UP_4015_png.rf.eaa1d0fe4f1ec4ee774f247da3e5cc00.jpg
# [DEBUG]	DETECTING BLOCKS...
# [DEBUG]	Using YOLOv8: /home/toto/ros_ws/src/UR5LegoVision/vision/yolov8-training/weights/best.pt
# image 1/1 /home/toto/ros_ws/src/UR5LegoVision/vision/dataset/test/images/v5_single_v2-X2-Y2-Z2_UP_4015_png.rf.eaa1d0fe4f1ec4ee774f247da3e5cc00.jpg: 640x640 1 X2-Y2-Z2, 560.7ms
# Speed: 1.6ms preprocess, 560.7ms inference, 4.0ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict
# [INFO]	Detected 1 object(s)
# [DEBUG]	1: X2-Y2-Z2 conf(0.99) xyxy(234, 192, 404, 383)
# <PIL.Image.Image image mode=RGB size=70x78>
# /home/toto/ros_ws/src/UR5LegoVision/vision/dataset/test/images/v5-X1-Y2-Z2_X1-Y2-Z2-TWINFILLET_DOWN_558_png.rf.0c5b6f73759a1b9c8d14064c7bd208cc.jpg
# [DEBUG]	DETECTING BLOCKS...
# [DEBUG]	Using YOLOv8: /home/toto/ros_ws/src/UR5LegoVision/vision/yolov8-training/weights/best.pt
# ...
