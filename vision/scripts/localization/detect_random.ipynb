# %%
import os
import random
from BlockDetect import BlockDetect

# Path to image folder
test_path = '/home/toto/ros_ws/src/UR5LegoVision/vision/dataset/test/images/'


# Number of sample to test
NUM_IMG = 10
for i in range(NUM_IMG):

    # Randomly pick img
    img_path = test_path + random.choice(os.listdir(test_path))
    print(img_path)

    legoDetect = BlockDetect(img_path)
# Out:
# /home/toto/ros_ws/src/UR5LegoVision/vision/dataset/test/images/v5_single_v2-X1-Y4-Z2_SIDE_3884_png.rf.bb0678f2a53c9f5ca04bfc5c40241221.jpg
# [DEBUG]	DETECTING BLOCKS...
# [DEBUG]	Using YOLOv8: /home/toto/ros_ws/src/UR5LegoVision/vision/yolov8-training/weights/best.pt
# image 1/1 /home/toto/ros_ws/src/UR5LegoVision/vision/dataset/test/images/v5_single_v2-X1-Y4-Z2_SIDE_3884_png.rf.bb0678f2a53c9f5ca04bfc5c40241221.jpg: 640x640 1 X1-Y4-Z2, 566.2ms
# Speed: 2.0ms preprocess, 566.2ms inference, 18.0ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict
# [INFO]	Detected 1 object(s)
# [DEBUG]	1: X1-Y4-Z2 conf(0.99) xyxy(210, 209, 514, 397)
# <PIL.Image.Image image mode=RGB size=70x43>
# /home/toto/ros_ws/src/UR5LegoVision/vision/dataset/test/images/v5_multi_v2-multiple_553_png.rf.459609ba60a028a52380b236e23c050a.jpg
# [DEBUG]	DETECTING BLOCKS...
# [DEBUG]	Using YOLOv8: /home/toto/ros_ws/src/UR5LegoVision/vision/yolov8-training/weights/best.pt
# image 1/1 /home/toto/ros_ws/src/UR5LegoVision/vision/dataset/test/images/v5_multi_v2-multiple_553_png.rf.459609ba60a028a52380b236e23c050a.jpg: 640x640 1 X1-Y1-Z2, 1 X1-Y2-Z1, 1 X1-Y2-Z2, 1 X1-Y2-Z2-CHAMFER, 1 X1-Y2-Z2-TWINFILLET, 1 X1-Y3-Z2, 1 X1-Y3-Z2-FILLET, 1 X1-Y4-Z1, 1 X1-Y4-Z2, 1 X2-Y2-Z2, 1 X2-Y2-Z2-FILLET, 694.6ms
# Speed: 33.8ms preprocess, 694.6ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict
# [INFO]	Detected 11 object(s)
# [DEBUG]	1: X2-Y2-Z2 conf(0.96) xyxy(525, 308, 578, 359)
# <PIL.Image.Image image mode=RGB size=70x67>
# [DEBUG]	2: X1-Y4-Z2 conf(0.96) xyxy(139, 352, 227, 410)
# <PIL.Image.Image image mode=RGB size=70x46>
# [DEBUG]	3: X2-Y2-Z2-FILLET conf(0.95) xyxy(276, 317, 325, 367)
# <PIL.Image.Image image mode=RGB size=70x71>
# [DEBUG]	4: X1-Y3-Z2 conf(0.95) xyxy(416, 352, 485, 395)
# <PIL.Image.Image image mode=RGB size=70x43>
# [DEBUG]	5: X1-Y2-Z2-CHAMFER conf(0.95) xyxy(372, 389, 427, 426)
# <PIL.Image.Image image mode=RGB size=70x47>
# [DEBUG]	6: X1-Y3-Z2-FILLET conf(0.95) xyxy(141, 301, 197, 336)
# <PIL.Image.Image image mode=RGB size=70x43>
# [DEBUG]	7: X1-Y4-Z1 conf(0.95) xyxy(276, 240, 338, 271)
# <PIL.Image.Image image mode=RGB size=70x35>
# [DEBUG]	8: X1-Y2-Z2-TWINFILLET conf(0.94) xyxy(176, 256, 213, 291)
# <PIL.Image.Image image mode=RGB size=70x66>
# [DEBUG]	9: X1-Y2-Z1 conf(0.94) xyxy(266, 294, 305, 324)
# <PIL.Image.Image image mode=RGB size=70x53>
# [DEBUG]	10: X1-Y2-Z2 conf(0.93) xyxy(363, 263, 404, 291)
# <PIL.Image.Image image mode=RGB size=70x47>
# [DEBUG]	11: X1-Y1-Z2 conf(0.92) xyxy(396, 243, 418, 276)
# <PIL.Image.Image image mode=RGB size=70x105>
# /home/toto/ros_ws/src/UR5LegoVision/vision/dataset/test/images/v5_single_v2-X1-Y3-Z2_UP_2272_png.rf.9c6fc75bd80475752c6d0fbad19d66fd.jpg
# [DEBUG]	DETECTING BLOCKS...
# [DEBUG]	Using YOLOv8: /home/toto/ros_ws/src/UR5LegoVision/vision/yolov8-training/weights/best.pt
# image 1/1 /home/toto/ros_ws/src/UR5LegoVision/vision/dataset/test/images/v5_single_v2-X1-Y3-Z2_UP_2272_png.rf.9c6fc75bd80475752c6d0fbad19d66fd.jpg: 640x640 1 X1-Y3-Z2, 596.8ms
# Speed: 49.5ms preprocess, 596.8ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict
# [INFO]	Detected 1 object(s)
# [DEBUG]	1: X1-Y3-Z2 conf(0.99) xyxy(219, 182, 405, 409)
# <PIL.Image.Image image mode=RGB size=70x85>
# /home/toto/ros_ws/src/UR5LegoVision/vision/dataset/test/images/v5-X1-Y2-Z1_X2-Y2-Z2_DOWN_470_png.rf.2a6a9eac01dab6603f87c6af9fcc1ef0.jpg
# [DEBUG]	DETECTING BLOCKS...
# [DEBUG]	Using YOLOv8: /home/toto/ros_ws/src/UR5LegoVision/vision/yolov8-training/weights/best.pt
# image 1/1 /home/toto/ros_ws/src/UR5LegoVision/vision/dataset/test/images/v5-X1-Y2-Z1_X2-Y2-Z2_DOWN_470_png.rf.2a6a9eac01dab6603f87c6af9fcc1ef0.jpg: 640x640 2 X1-Y2-Z1s, 2 X2-Y2-Z2s, 609.5ms
# Speed: 47.2ms preprocess, 609.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict
# [INFO]	Detected 4 object(s)
# [DEBUG]	1: X2-Y2-Z2 conf(0.99) xyxy(415, 204, 587, 372)
# <PIL.Image.Image image mode=RGB size=70x68>
# [DEBUG]	2: X2-Y2-Z2 conf(0.99) xyxy(56, 229, 214, 399)
# <PIL.Image.Image image mode=RGB size=70x75>
# [DEBUG]	3: X1-Y2-Z1 conf(0.98) xyxy(274, 121, 340, 246)
# <PIL.Image.Image image mode=RGB size=70x132>
# [DEBUG]	4: X1-Y2-Z1 conf(0.98) xyxy(295, 397, 383, 558)
# <PIL.Image.Image image mode=RGB size=70x128>
# /home/toto/ros_ws/src/UR5LegoVision/vision/dataset/test/images/v5_single_v2-X1-Y4-Z1_DOWN_3236_png.rf.0f3b12c07f0908b96c12aac5f88b155f.jpg
# [DEBUG]	DETECTING BLOCKS...
# [DEBUG]	Using YOLOv8: /home/toto/ros_ws/src/UR5LegoVision/vision/yolov8-training/weights/best.pt
# image 1/1 /home/toto/ros_ws/src/UR5LegoVision/vision/dataset/test/images/v5_single_v2-X1-Y4-Z1_DOWN_3236_png.rf.0f3b12c07f0908b96c12aac5f88b155f.jpg: 640x640 1 X1-Y4-Z1, 607.1ms
# Speed: 26.1ms preprocess, 607.1ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict
# [INFO]	Detected 1 object(s)
# [DEBUG]	1: X1-Y4-Z1 conf(0.98) xyxy(177, 189, 478, 424)
# <PIL.Image.Image image mode=RGB size=70x54>
# /home/toto/ros_ws/src/UR5LegoVision/vision/dataset/test/images/v5-X1-Y4-Z1_X2-Y2-Z2-FILLET_UP_1382_png.rf.d65ca064cfd1a9810e05f230971c9cc9.jpg
# [DEBUG]	DETECTING BLOCKS...
# [DEBUG]	Using YOLOv8: /home/toto/ros_ws/src/UR5LegoVision/vision/yolov8-training/weights/best.pt
# image 1/1 /home/toto/ros_ws/src/UR5LegoVision/vision/dataset/test/images/v5-X1-Y4-Z1_X2-Y2-Z2-FILLET_UP_1382_png.rf.d65ca064cfd1a9810e05f230971c9cc9.jpg: 640x640 2 X1-Y4-Z1s, 2 X2-Y2-Z2-FILLETs, 525.5ms
# Speed: 15.8ms preprocess, 525.5ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict
# [INFO]	Detected 4 object(s)
# [DEBUG]	1: X2-Y2-Z2-FILLET conf(0.99) xyxy(308, 127, 461, 280)
# <PIL.Image.Image image mode=RGB size=70x70>
# [DEBUG]	2: X2-Y2-Z2-FILLET conf(0.99) xyxy(142, 373, 333, 571)
# <PIL.Image.Image image mode=RGB size=70x72>
# [DEBUG]	3: X1-Y4-Z1 conf(0.98) xyxy(58, 192, 296, 344)
# <PIL.Image.Image image mode=RGB size=70x44>
# [DEBUG]	4: X1-Y4-Z1 conf(0.98) xyxy(344, 306, 620, 478)
# <PIL.Image.Image image mode=RGB size=70x43>
# /home/toto/ros_ws/src/UR5LegoVision/vision/dataset/test/images/v5_single_v2-X2-Y2-Z2_UP_4017_png.rf.ceae179f2abe63a76784e21100154360.jpg
# [DEBUG]	DETECTING BLOCKS...
# [DEBUG]	Using YOLOv8: /home/toto/ros_ws/src/UR5LegoVision/vision/yolov8-training/weights/best.pt
# image 1/1 /home/toto/ros_ws/src/UR5LegoVision/vision/dataset/test/images/v5_single_v2-X2-Y2-Z2_UP_4017_png.rf.ceae179f2abe63a76784e21100154360.jpg: 640x640 1 X2-Y2-Z2, 556.4ms
# Speed: 25.6ms preprocess, 556.4ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict
# [INFO]	Detected 1 object(s)
# [DEBUG]	1: X2-Y2-Z2 conf(0.99) xyxy(214, 188, 415, 396)
# <PIL.Image.Image image mode=RGB size=70x72>
# /home/toto/ros_ws/src/UR5LegoVision/vision/dataset/test/images/v5_single_v2-X1-Y3-Z2-FILLET_SIDE_2973_png.rf.d2a79bf03c3dbfd5abe9e1bba8b1636b.jpg
# [DEBUG]	DETECTING BLOCKS...
# [DEBUG]	Using YOLOv8: /home/toto/ros_ws/src/UR5LegoVision/vision/yolov8-training/weights/best.pt
# image 1/1 /home/toto/ros_ws/src/UR5LegoVision/vision/dataset/test/images/v5_single_v2-X1-Y3-Z2-FILLET_SIDE_2973_png.rf.d2a79bf03c3dbfd5abe9e1bba8b1636b.jpg: 640x640 1 X1-Y3-Z2-FILLET, 613.0ms
# Speed: 10.4ms preprocess, 613.0ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict
# [INFO]	Detected 1 object(s)
# [DEBUG]	1: X1-Y3-Z2-FILLET conf(0.99) xyxy(148, 213, 356, 418)
# <PIL.Image.Image image mode=RGB size=70x68>
# /home/toto/ros_ws/src/UR5LegoVision/vision/dataset/test/images/v5_single_v2-X1-Y2-Z2-CHAMFER_DOWN_1489_png.rf.17c468141a54e8a711f8db5e5b2c1b83.jpg
# [DEBUG]	DETECTING BLOCKS...
# [DEBUG]	Using YOLOv8: /home/toto/ros_ws/src/UR5LegoVision/vision/yolov8-training/weights/best.pt
# image 1/1 /home/toto/ros_ws/src/UR5LegoVision/vision/dataset/test/images/v5_single_v2-X1-Y2-Z2-CHAMFER_DOWN_1489_png.rf.17c468141a54e8a711f8db5e5b2c1b83.jpg: 640x640 1 X1-Y2-Z2-CHAMFER, 500.2ms
# Speed: 44.7ms preprocess, 500.2ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict
# [INFO]	Detected 1 object(s)
# [DEBUG]	1: X1-Y2-Z2-CHAMFER conf(0.99) xyxy(226, 193, 414, 376)
# <PIL.Image.Image image mode=RGB size=70x68>
# /home/toto/ros_ws/src/UR5LegoVision/vision/dataset/test/images/v5_single_v2-X1-Y2-Z2-TWINFILLET_SIDE_2106_png.rf.04356a99aa489f1704a1f8ca19bb4aca.jpg
# [DEBUG]	DETECTING BLOCKS...
# [DEBUG]	Using YOLOv8: /home/toto/ros_ws/src/UR5LegoVision/vision/yolov8-training/weights/best.pt
# image 1/1 /home/toto/ros_ws/src/UR5LegoVision/vision/dataset/test/images/v5_single_v2-X1-Y2-Z2-TWINFILLET_SIDE_2106_png.rf.04356a99aa489f1704a1f8ca19bb4aca.jpg: 640x640 1 X1-Y2-Z2-TWINFILLET, 550.3ms
# Speed: 24.7ms preprocess, 550.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict
# [INFO]	Detected 1 object(s)
# [DEBUG]	1: X1-Y2-Z2-TWINFILLET conf(0.98) xyxy(177, 239, 334, 400)
# <PIL.Image.Image image mode=RGB size=70x71>
