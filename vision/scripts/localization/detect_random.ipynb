# %%
import os
import random
from BlockDetect import BlockDetect

# Path to image folder
test_path = '/home/toto/ros_ws/src/UR5LegoVision/vision/dataset/test/images/'


# Number of sample to test
NUM_IMG = 10
for i in range(NUM_IMG):

    # Randomly pick img
    img_path = test_path + random.choice(os.listdir(test_path))
    print(img_path)

    legoDetect = BlockDetect(img_path)
# Out:
# /home/toto/ros_ws/src/UR5LegoVision/vision/dataset/test/images/v5_multi_multi_v2-multiple_157_png.rf.445ec9f1aca7938ed0ee7471a0c921bb.jpg
# [DEBUG]	DETECTING BLOCKS...
# [DEBUG]	Using YOLOv8: /home/toto/ros_ws/src/UR5LegoVision/vision/yolov8-training/weights/best.pt
# image 1/1 /home/toto/ros_ws/src/UR5LegoVision/vision/dataset/test/images/v5_multi_multi_v2-multiple_157_png.rf.445ec9f1aca7938ed0ee7471a0c921bb.jpg: 640x640 4 X1-Y1-Z2s, 4 X1-Y2-Z1s, 4 X1-Y2-Z2s, 4 X1-Y2-Z2-CHAMFERs, 4 X1-Y2-Z2-TWINFILLETs, 4 X1-Y3-Z2s, 4 X1-Y3-Z2-FILLETs, 4 X1-Y4-Z1s, 4 X1-Y4-Z2s, 4 X2-Y2-Z2s, 4 X2-Y2-Z2-FILLETs, 536.2ms
# Speed: 1.3ms preprocess, 536.2ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict
# [INFO]	Detected 44 object(s)
# [DEBUG]	1: X1-Y4-Z2 conf(0.96) xyxy(311, 422, 359, 476)
# <PIL.Image.Image image mode=RGB size=70x78>
# [DEBUG]	2: X1-Y4-Z1 conf(0.96) xyxy(364, 504, 427, 546)
# <PIL.Image.Image image mode=RGB size=70x46>
# [DEBUG]	3: X1-Y4-Z2 conf(0.95) xyxy(511, 389, 550, 445)
# <PIL.Image.Image image mode=RGB size=70x100>
# [DEBUG]	4: X1-Y4-Z2 conf(0.95) xyxy(506, 301, 561, 334)
# <PIL.Image.Image image mode=RGB size=70x42>
# [DEBUG]	5: X1-Y4-Z1 conf(0.95) xyxy(371, 190, 408, 222)
# <PIL.Image.Image image mode=RGB size=70x60>
# [DEBUG]	6: X1-Y3-Z2-FILLET conf(0.95) xyxy(308, 226, 341, 257)
# <PIL.Image.Image image mode=RGB size=70x65>
# [DEBUG]	7: X1-Y3-Z2 conf(0.95) xyxy(571, 375, 607, 418)
# <PIL.Image.Image image mode=RGB size=70x83>
# [DEBUG]	8: X2-Y2-Z2-FILLET conf(0.95) xyxy(292, 297, 324, 331)
# <PIL.Image.Image image mode=RGB size=70x74>
# [DEBUG]	9: X1-Y4-Z2 conf(0.95) xyxy(409, 371, 443, 428)
# <PIL.Image.Image image mode=RGB size=70x117>
# [DEBUG]	10: X1-Y4-Z1 conf(0.95) xyxy(218, 493, 280, 525)
# <PIL.Image.Image image mode=RGB size=70x36>
# [DEBUG]	11: X1-Y3-Z2 conf(0.95) xyxy(539, 344, 584, 375)
# <PIL.Image.Image image mode=RGB size=70x48>
# [DEBUG]	12: X1-Y2-Z2-TWINFILLET conf(0.95) xyxy(351, 381, 381, 411)
# <PIL.Image.Image image mode=RGB size=70x70>
# [DEBUG]	13: X1-Y2-Z2 conf(0.95) xyxy(164, 537, 202, 572)
# <PIL.Image.Image image mode=RGB size=70x64>
# [DEBUG]	14: X1-Y4-Z1 conf(0.95) xyxy(315, 337, 367, 361)
# <PIL.Image.Image image mode=RGB size=70x32>
# [DEBUG]	15: X2-Y2-Z2 conf(0.94) xyxy(274, 363, 304, 400)
# <PIL.Image.Image image mode=RGB size=70x86>
# [DEBUG]	16: X1-Y3-Z2-FILLET conf(0.94) xyxy(108, 383, 152, 417)
# <PIL.Image.Image image mode=RGB size=70x54>
# [DEBUG]	17: X2-Y2-Z2-FILLET conf(0.94) xyxy(91, 229, 120, 261)
# <PIL.Image.Image image mode=RGB size=70x77>
# [DEBUG]	18: X2-Y2-Z2 conf(0.94) xyxy(138, 275, 166, 307)
# <PIL.Image.Image image mode=RGB size=70x80>
# [DEBUG]	19: X1-Y2-Z2-CHAMFER conf(0.94) xyxy(225, 369, 253, 399)
# <PIL.Image.Image image mode=RGB size=70x75>
# [DEBUG]	20: X1-Y3-Z2 conf(0.94) xyxy(232, 189, 266, 218)
# <PIL.Image.Image image mode=RGB size=70x59>
# [DEBUG]	21: X2-Y2-Z2 conf(0.94) xyxy(174, 243, 208, 278)
# <PIL.Image.Image image mode=RGB size=70x72>
# [DEBUG]	22: X1-Y2-Z2 conf(0.94) xyxy(175, 399, 206, 434)
# <PIL.Image.Image image mode=RGB size=70x79>
# [DEBUG]	23: X2-Y2-Z2 conf(0.94) xyxy(296, 387, 328, 425)
# <PIL.Image.Image image mode=RGB size=70x83>
# [DEBUG]	24: X1-Y2-Z2 conf(0.94) xyxy(465, 436, 500, 462)
# <PIL.Image.Image image mode=RGB size=70x52>
# [DEBUG]	25: X2-Y2-Z2-FILLET conf(0.94) xyxy(442, 285, 478, 318)
# <PIL.Image.Image image mode=RGB size=70x64>
# [DEBUG]	26: X1-Y3-Z2-FILLET conf(0.94) xyxy(476, 272, 510, 304)
# <PIL.Image.Image image mode=RGB size=70x65>
# [DEBUG]	27: X1-Y2-Z2-CHAMFER conf(0.93) xyxy(465, 372, 497, 398)
# <PIL.Image.Image image mode=RGB size=70x56>
# [DEBUG]	28: X2-Y2-Z2-FILLET conf(0.93) xyxy(66, 248, 95, 280)
# <PIL.Image.Image image mode=RGB size=70x77>
# [DEBUG]	29: X1-Y2-Z1 conf(0.93) xyxy(160, 455, 194, 486)
# <PIL.Image.Image image mode=RGB size=70x63>
# [DEBUG]	30: X1-Y3-Z2 conf(0.93) xyxy(180, 315, 199, 358)
# <PIL.Image.Image image mode=RGB size=70x158>
# [DEBUG]	31: X1-Y3-Z2-FILLET conf(0.93) xyxy(398, 237, 435, 258)
# <PIL.Image.Image image mode=RGB size=70x39>
# [DEBUG]	32: X1-Y2-Z2-CHAMFER conf(0.93) xyxy(259, 249, 281, 273)
# <PIL.Image.Image image mode=RGB size=70x76>
# [DEBUG]	33: X1-Y1-Z2 conf(0.92) xyxy(415, 452, 434, 477)
# <PIL.Image.Image image mode=RGB size=70x92>
# [DEBUG]	34: X1-Y2-Z2-TWINFILLET conf(0.92) xyxy(81, 282, 108, 306)
# <PIL.Image.Image image mode=RGB size=70x62>
# [DEBUG]	35: X1-Y2-Z2 conf(0.92) xyxy(343, 250, 364, 275)
# <PIL.Image.Image image mode=RGB size=70x83>
# [DEBUG]	36: X1-Y2-Z1 conf(0.92) xyxy(440, 251, 466, 272)
# <PIL.Image.Image image mode=RGB size=70x56>
# [DEBUG]	37: X1-Y2-Z2-CHAMFER conf(0.92) xyxy(193, 211, 212, 240)
# <PIL.Image.Image image mode=RGB size=70x106>
# [DEBUG]	38: X1-Y2-Z1 conf(0.92) xyxy(371, 248, 393, 273)
# <PIL.Image.Image image mode=RGB size=70x79>
# [DEBUG]	39: X1-Y2-Z2-TWINFILLET conf(0.92) xyxy(403, 311, 420, 339)
# <PIL.Image.Image image mode=RGB size=70x115>
# [DEBUG]	40: X1-Y1-Z2 conf(0.92) xyxy(91, 313, 110, 335)
# <PIL.Image.Image image mode=RGB size=70x81>
# [DEBUG]	41: X1-Y2-Z1 conf(0.91) xyxy(357, 224, 381, 245)
# <PIL.Image.Image image mode=RGB size=70x61>
# [DEBUG]	42: X1-Y2-Z2-TWINFILLET conf(0.91) xyxy(337, 172, 359, 191)
# <PIL.Image.Image image mode=RGB size=70x60>
# [DEBUG]	43: X1-Y1-Z2 conf(0.91) xyxy(417, 261, 441, 280)
# <PIL.Image.Image image mode=RGB size=70x55>
# [DEBUG]	44: X1-Y1-Z2 conf(0.91) xyxy(307, 181, 326, 200)
# <PIL.Image.Image image mode=RGB size=70x70>
# /home/toto/ros_ws/src/UR5LegoVision/vision/dataset/test/images/v5_single_v2-X1-Y1-Z2_SIDE_340_png.rf.f2a596dc24a19d14d1cdbe08830c68c8.jpg
# [DEBUG]	DETECTING BLOCKS...
# [DEBUG]	Using YOLOv8: /home/toto/ros_ws/src/UR5LegoVision/vision/yolov8-training/weights/best.pt
# image 1/1 /home/toto/ros_ws/src/UR5LegoVision/vision/dataset/test/images/v5_single_v2-X1-Y1-Z2_SIDE_340_png.rf.f2a596dc24a19d14d1cdbe08830c68c8.jpg: 640x640 1 X1-Y1-Z2, 1192.6ms
# Speed: 36.9ms preprocess, 1192.6ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict
# [INFO]	Detected 1 object(s)
# [DEBUG]	1: X1-Y1-Z2 conf(0.98) xyxy(182, 268, 340, 404)
# <PIL.Image.Image image mode=RGB size=70x60>
# /home/toto/ros_ws/src/UR5LegoVision/vision/dataset/test/images/lego_2197_catasta7l_jpg.rf.781dfbf961d41efb479e41f25123ac59.jpg
# [DEBUG]	DETECTING BLOCKS...
# [DEBUG]	Using YOLOv8: /home/toto/ros_ws/src/UR5LegoVision/vision/yolov8-training/weights/best.pt
# image 1/1 /home/toto/ros_ws/src/UR5LegoVision/vision/dataset/test/images/lego_2197_catasta7l_jpg.rf.781dfbf961d41efb479e41f25123ac59.jpg: 448x640 1 X1-Y2-Z2, 1 X1-Y3-Z2, 1 X1-Y3-Z2-FILLET, 1 X1-Y4-Z1, 2 X2-Y2-Z2s, 1 X2-Y2-Z2-FILLET, 581.7ms
# Speed: 9.2ms preprocess, 581.7ms inference, 1.1ms postprocess per image at shape (1, 3, 448, 640)
# Results saved to runs/detect/predict
# [INFO]	Detected 7 object(s)
# [DEBUG]	1: X1-Y4-Z1 conf(0.98) xyxy(326, 180, 450, 284)
# <PIL.Image.Image image mode=RGB size=70x58>
# [DEBUG]	2: X2-Y2-Z2-FILLET conf(0.98) xyxy(165, 171, 258, 304)
# <PIL.Image.Image image mode=RGB size=70x100>
# [DEBUG]	3: X1-Y3-Z2 conf(0.98) xyxy(252, 287, 379, 362)
# <PIL.Image.Image image mode=RGB size=70x41>
# [DEBUG]	4: X1-Y3-Z2-FILLET conf(0.97) xyxy(386, 94, 498, 176)
# <PIL.Image.Image image mode=RGB size=70x51>
# [DEBUG]	5: X2-Y2-Z2 conf(0.97) xyxy(289, 123, 362, 202)
# <PIL.Image.Image image mode=RGB size=70x75>
# [DEBUG]	6: X2-Y2-Z2 conf(0.96) xyxy(140, 120, 240, 232)
# <PIL.Image.Image image mode=RGB size=70x78>
# [DEBUG]	7: X1-Y2-Z2 conf(0.96) xyxy(203, 79, 254, 176)
# <PIL.Image.Image image mode=RGB size=70x133>
# /home/toto/ros_ws/src/UR5LegoVision/vision/dataset/test/images/v5_single_v2-X1-Y2-Z1_SIDE_853_png.rf.9000269ec1dc640bac779bc2080e028f.jpg
# [DEBUG]	DETECTING BLOCKS...
# [DEBUG]	Using YOLOv8: /home/toto/ros_ws/src/UR5LegoVision/vision/yolov8-training/weights/best.pt
# image 1/1 /home/toto/ros_ws/src/UR5LegoVision/vision/dataset/test/images/v5_single_v2-X1-Y2-Z1_SIDE_853_png.rf.9000269ec1dc640bac779bc2080e028f.jpg: 640x640 1 X1-Y2-Z1, 732.4ms
# Speed: 21.5ms preprocess, 732.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict
# [INFO]	Detected 1 object(s)
# [DEBUG]	1: X1-Y2-Z1 conf(0.98) xyxy(221, 241, 384, 361)
# <PIL.Image.Image image mode=RGB size=70x51>
# /home/toto/ros_ws/src/UR5LegoVision/vision/dataset/test/images/v5_single_v2-X1-Y1-Z2_UP_58_png.rf.81412c5f0ada75fb752c5c826d9d329e.jpg
# [DEBUG]	DETECTING BLOCKS...
# [DEBUG]	Using YOLOv8: /home/toto/ros_ws/src/UR5LegoVision/vision/yolov8-training/weights/best.pt
# image 1/1 /home/toto/ros_ws/src/UR5LegoVision/vision/dataset/test/images/v5_single_v2-X1-Y1-Z2_UP_58_png.rf.81412c5f0ada75fb752c5c826d9d329e.jpg: 640x640 1 X1-Y1-Z2, 642.3ms
# Speed: 50.1ms preprocess, 642.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict
# [INFO]	Detected 1 object(s)
# [DEBUG]	1: X1-Y1-Z2 conf(0.98) xyxy(265, 229, 373, 382)
# <PIL.Image.Image image mode=RGB size=70x99>
# /home/toto/ros_ws/src/UR5LegoVision/vision/dataset/test/images/v5_single_v2-X1-Y3-Z2_UP_2183_png.rf.5ff7a6cabafdd188141063ecd2120b11.jpg
# [DEBUG]	DETECTING BLOCKS...
# [DEBUG]	Using YOLOv8: /home/toto/ros_ws/src/UR5LegoVision/vision/yolov8-training/weights/best.pt
# image 1/1 /home/toto/ros_ws/src/UR5LegoVision/vision/dataset/test/images/v5_single_v2-X1-Y3-Z2_UP_2183_png.rf.5ff7a6cabafdd188141063ecd2120b11.jpg: 640x640 1 X1-Y3-Z2, 629.9ms
# Speed: 4.4ms preprocess, 629.9ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict
# [INFO]	Detected 1 object(s)
# [DEBUG]	1: X1-Y3-Z2 conf(0.99) xyxy(206, 192, 425, 444)
# <PIL.Image.Image image mode=RGB size=70x80>
# /home/toto/ros_ws/src/UR5LegoVision/vision/dataset/test/images/v5-X1-Y1-Z2_X2-Y2-Z2-FILLET_UP_247_png.rf.3574235eb09a6c374e7cf5d93ea2c015.jpg
# [DEBUG]	DETECTING BLOCKS...
# [DEBUG]	Using YOLOv8: /home/toto/ros_ws/src/UR5LegoVision/vision/yolov8-training/weights/best.pt
# image 1/1 /home/toto/ros_ws/src/UR5LegoVision/vision/dataset/test/images/v5-X1-Y1-Z2_X2-Y2-Z2-FILLET_UP_247_png.rf.3574235eb09a6c374e7cf5d93ea2c015.jpg: 640x640 2 X1-Y1-Z2s, 2 X2-Y2-Z2-FILLETs, 611.1ms
# Speed: 26.3ms preprocess, 611.1ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict
# [INFO]	Detected 4 object(s)
# [DEBUG]	1: X2-Y2-Z2-FILLET conf(0.99) xyxy(284, 378, 468, 575)
# <PIL.Image.Image image mode=RGB size=70x74>
# [DEBUG]	2: X2-Y2-Z2-FILLET conf(0.99) xyxy(215, 104, 352, 268)
# <PIL.Image.Image image mode=RGB size=70x83>
# [DEBUG]	3: X1-Y1-Z2 conf(0.98) xyxy(434, 220, 526, 331)
# <PIL.Image.Image image mode=RGB size=70x84>
# [DEBUG]	4: X1-Y1-Z2 conf(0.98) xyxy(106, 297, 194, 408)
# <PIL.Image.Image image mode=RGB size=70x88>
# /home/toto/ros_ws/src/UR5LegoVision/vision/dataset/test/images/v5_single_v2-X1-Y3-Z2-FILLET_UP_2617_png.rf.02523715889c66bbdc01ce57ec27adca.jpg
# [DEBUG]	DETECTING BLOCKS...
# [DEBUG]	Using YOLOv8: /home/toto/ros_ws/src/UR5LegoVision/vision/yolov8-training/weights/best.pt
# image 1/1 /home/toto/ros_ws/src/UR5LegoVision/vision/dataset/test/images/v5_single_v2-X1-Y3-Z2-FILLET_UP_2617_png.rf.02523715889c66bbdc01ce57ec27adca.jpg: 640x640 1 X1-Y3-Z2-FILLET, 800.7ms
# Speed: 1.9ms preprocess, 800.7ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict
# [INFO]	Detected 1 object(s)
# [DEBUG]	1: X1-Y3-Z2-FILLET conf(0.99) xyxy(191, 243, 438, 422)
# <PIL.Image.Image image mode=RGB size=70x50>
# /home/toto/ros_ws/src/UR5LegoVision/vision/dataset/test/images/v5_single_v2-X2-Y2-Z2_DOWN_4078_png.rf.5066f6e762f10b9fb3e8d86994fac523.jpg
# [DEBUG]	DETECTING BLOCKS...
# [DEBUG]	Using YOLOv8: /home/toto/ros_ws/src/UR5LegoVision/vision/yolov8-training/weights/best.pt
# image 1/1 /home/toto/ros_ws/src/UR5LegoVision/vision/dataset/test/images/v5_single_v2-X2-Y2-Z2_DOWN_4078_png.rf.5066f6e762f10b9fb3e8d86994fac523.jpg: 640x640 1 X2-Y2-Z2, 730.9ms
# Speed: 23.5ms preprocess, 730.9ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict
# [INFO]	Detected 1 object(s)
# [DEBUG]	1: X2-Y2-Z2 conf(0.99) xyxy(230, 190, 409, 391)
# <PIL.Image.Image image mode=RGB size=70x78>
# /home/toto/ros_ws/src/UR5LegoVision/vision/dataset/test/images/v5_single_v2-X1-Y2-Z2-TWINFILLET_DOWN_1921_png.rf.fbd4ff15d30e397815c16086c027db1a.jpg
# [DEBUG]	DETECTING BLOCKS...
# [DEBUG]	Using YOLOv8: /home/toto/ros_ws/src/UR5LegoVision/vision/yolov8-training/weights/best.pt
# image 1/1 /home/toto/ros_ws/src/UR5LegoVision/vision/dataset/test/images/v5_single_v2-X1-Y2-Z2-TWINFILLET_DOWN_1921_png.rf.fbd4ff15d30e397815c16086c027db1a.jpg: 640x640 1 X1-Y2-Z2-TWINFILLET, 646.9ms
# Speed: 4.4ms preprocess, 646.9ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict
# [INFO]	Detected 1 object(s)
# [DEBUG]	1: X1-Y2-Z2-TWINFILLET conf(0.99) xyxy(226, 193, 414, 361)
# <PIL.Image.Image image mode=RGB size=70x62>
