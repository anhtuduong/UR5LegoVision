# %%
from BlockDetect import BlockDetect

# Imgage path
IMG_PATH = '/home/toto/Pictures/Screenshot from 2023-11-14 00-17-10.png' 

legoDetect = BlockDetect(IMG_PATH)
# Out:
# [DEBUG]	DETECTING BLOCKS...
# [DEBUG]	Using YOLOv8: /home/toto/ros_ws/src/UR5LegoVision/vision/yolov8-training/weights/best.pt
# image 1/1 /home/toto/Pictures/Screenshot from 2023-11-14 00-17-10.png: 608x640 1 X1-Y1-Z2, 1 X1-Y3-Z2, 478.5ms
# Speed: 6.4ms preprocess, 478.5ms inference, 1.1ms postprocess per image at shape (1, 3, 608, 640)
# Results saved to runs/detect/predict
# [INFO]	Detected 2 object(s)
# [DEBUG]	1: X1-Y1-Z2 conf(0.93) xyxy(370, 580, 396, 629)
# <PIL.Image.Image image mode=RGBA size=70x131>
# [DEBUG]	2: X1-Y3-Z2 conf(0.33) xyxy(333, 627, 434, 687)
# <PIL.Image.Image image mode=RGBA size=70x41>
