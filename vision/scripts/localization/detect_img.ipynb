# %%
from BlockDetect import BlockDetect

# Imgage path
IMG_PATH = '/home/toto/ros_ws/src/UR5LegoVision/lego_builder/output/output.png' 

legoDetect = BlockDetect(IMG_PATH)
# Out:
# [DEBUG]	DETECTING BLOCKS...
# [DEBUG]	Using YOLOv8: /home/toto/ros_ws/src/UR5LegoVision/vision/yolov8-training/weights/best.pt
# image 1/1 /home/toto/ros_ws/src/UR5LegoVision/lego_builder/output/output.png: 640x640 1 X1-Y1-Z2, 1 X1-Y2-Z1, 1 X1-Y2-Z2, 1 X1-Y2-Z2-CHAMFER, 1 X1-Y2-Z2-TWINFILLET, 1 X1-Y3-Z2, 1 X1-Y3-Z2-FILLET, 640.5ms
# Speed: 4.3ms preprocess, 640.5ms inference, 15.0ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict
# [INFO]	Detected 7 object(s)
# [DEBUG]	1: X1-Y3-Z2-FILLET conf(0.98) xyxy(254, 186, 318, 225)
# <PIL.Image.Image image mode=RGBA size=70x42>
# [DEBUG]	2: X1-Y3-Z2 conf(0.98) xyxy(162, 184, 227, 223)
# <PIL.Image.Image image mode=RGBA size=70x42>
# [DEBUG]	3: X1-Y2-Z2-CHAMFER conf(0.97) xyxy(251, 70, 294, 109)
# <PIL.Image.Image image mode=RGBA size=70x63>
# [DEBUG]	4: X1-Y2-Z2 conf(0.96) xyxy(175, 65, 218, 104)
# <PIL.Image.Image image mode=RGBA size=70x63>
# [DEBUG]	5: X1-Y2-Z2-TWINFILLET conf(0.96) xyxy(69, 175, 112, 213)
# <PIL.Image.Image image mode=RGBA size=70x61>
# [DEBUG]	6: X1-Y2-Z1 conf(0.96) xyxy(106, 68, 149, 94)
# <PIL.Image.Image image mode=RGBA size=70x42>
# [DEBUG]	7: X1-Y1-Z2 conf(0.95) xyxy(58, 60, 79, 99)
# <PIL.Image.Image image mode=RGBA size=70x130>
