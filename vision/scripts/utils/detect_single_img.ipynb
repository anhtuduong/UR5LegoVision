# %%
# Resolve paths
import os
import sys
CWD = os.getcwd()
SCRIPTS_PATH = os.path.abspath(os.path.join(CWD, ".."))
VISION_PATH = os.path.abspath(os.path.join(SCRIPTS_PATH, ".."))
ROOT = os.path.abspath(os.path.join(VISION_PATH, ".."))
if str(ROOT) not in sys.path:
    sys.path.append(str(ROOT))  # add ROOT to PATH
print(ROOT)
# Out:
# /home/toto/ros_ws/src/UR5BlokVision

# %%
from vision.constants import IMG_ZED_PATH
from vision.scripts.localization.BlockDetect import BlockDetect

img_path = IMG_ZED_PATH
legoDetect = BlockDetect(img_path)
# Out:
# Downloading: "https://github.com/ultralytics/yolov5/zipball/master" to /home/toto/.cache/torch/hub/master.zip
# YOLOv5 🚀 2023-5-13 Python-3.8.10 torch-1.13.1+cu117 CPU
#
# Fusing layers...
# YOLOv5l summary: 267 layers, 46162128 parameters, 0 gradients, 107.8 GFLOPs
# Adding AutoShape...
# <PIL.Image.Image image mode=RGB size=1920x1080>
# /home/toto/ros_ws/src/UR5BlokVision/logs/img_ZED_cam.png
# img size: 1920 x 1080
# Detected 1 object(s)
#
# 1
# <PIL.Image.Image image mode=RGB size=70x46>
# class = X1-Y3-Z2-FILLET
# id = 6
# confidence = 0.98
# center_point = (948, 621)
# center_point_uv = (972, 621)
# --> point cloud = ()
# --> point world = ()
#
# None
